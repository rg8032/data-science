# %%
import requests

# %%
url = "https://zillow56.p.rapidapi.com/search"

querystring = {"location":"allegheny county, pa","output":"json","status":"forSale","sortSelection":"priorityscore","listing_type":"by_agent","doz":"any"}

headers = {
	"x-rapidapi-key": "3eeec38e72msh0889974383b2252p1b71f3jsn386c577de5a5",
	"x-rapidapi-host": "zillow56.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'results': [{'bathrooms': 2.0, 'bedrooms': 5.0, 'city': 'Pittsburgh', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': -1, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'MULTI_FAMILY', 'imgSrc': 'https://photos.zillowstatic.com/fp/937ea1b898f54c28a1103d9bcf7bb14e-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 40.42082, 'listing_sub_type': {'is_FSBA': True}, 'longitude': -80.00264, 'lotAreaUnit': 'sqft', 'lotAreaValue': 6063.552, 'price': 140000.0, 'priceForHDP': 140000.0, 'rentZestimate': 1164, 'shouldHighlight': False, 'state': 'PA', 'streetAddress': '258 E Warrington Ave', 'taxAssessedValue': 48400.0, 'timeOnZillow': 2091000, 'zestimate': 173300, 'zipcode': '15210', 'zpid': 11324177}, {'bathrooms': 3.0, 'bedrooms': 3.0, 'city': 'Bethel Park', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': -
# ...

# %%
len(response.json()['results'])
# Out:
# 41

# %%
response.json()['results'][40]
# Out:
# {'bathrooms': 3.0,
#  'bedrooms': 3.0,
#  'city': 'Pittsburgh',
#  'country': 'USA',
#  'currency': 'USD',
#  'datePriceChanged': 1731398400000,
#  'daysOnZillow': -1,
#  'homeStatus': 'FOR_SALE',
#  'homeStatusForHDP': 'FOR_SALE',
#  'homeType': 'SINGLE_FAMILY',
#  'imgSrc': 'https://photos.zillowstatic.com/fp/d14bd28da5d44baf6407b91a879ea29d-p_e.jpg',
#  'isFeatured': False,
#  'isNonOwnerOccupied': True,
#  'isPreforeclosureAuction': False,
#  'isPremierBuilder': False,
#  'isShowcaseListing': False,
#  'isUnmappable': False,
#  'isZillowOwned': False,
#  'latitude': 40.481792,
#  'listing_sub_type': {'is_FSBA': True},
#  'livingArea': 1600.0,
#  'longitude': -79.74465,
#  'lotAreaUnit': 'sqft',
#  'lotAreaValue': 8999.496,
#  'price': 330000.0,
#  'priceChange': 161000,
#  'priceForHDP': 330000.0,
#  'rentZestimate': 1819,
#  'shouldHighlight': False,
#  'state': 'PA',
#  'streetAddress': '250 Darlan Hill Dr',
#  'taxAssessedValue': 116000.0,
#  'timeOnZillow': 88288000,
# ...
