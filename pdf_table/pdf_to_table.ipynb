# %%
import camelot

# Replace 'your_pdf_file.pdf' with the path to your PDF file
tables = camelot.read_pdf(filepath='April-Sale-List.pdf', pages='all', flavor='stream')


tables[0]
# Out:
# <Table shape=(8, 7)>

# %%
t = tables[0]

# %%
for t in tables:
    display(t.df)
# Out:
#                                                    0  \
# 0
# 1
# 2
# 3
# 4                                            strives
# 5
# 6
# 7  ﬁlings, notices to this Ofﬁce by counsel, or r...
#
#                                                    1                      2  \
# 0
# 1  The Allegheny County Sheriff's Ofﬁce maintains...
# 2  sale  lists, bid  lists, postponements  and  s...
# 3  information related to real estate exposed to ...
# 4                                        to  provide  timely  and  accurate
# 5  information presented here reﬂects the most cu...
# 6  information  is  generally  updated  bi-weekly...
# 7
#
#               3                      4     5    6
# 0    DISCLAIMER
# 1
# 2
# 3
# 4  information,  it  cannot  guarantee  that  the
# 5
# 6
# 7
#                                                    0
# 0     Highlands School District\nANDREWS & PRICE ESQ
# 1      Comments:\nO/C FREE & CLEAR TO HIGHEST BIDDER
# ...

# %%
import tabula

# %%
df = tabula.read_pdf('April-Sale-List.pdf', pages='6', lattice=True)

# %%
df[0]
# Out:
#   SaleCase NumberSale TypeStatusTractsCost & Tax Bid\rSvs3129.2\r3129.3OK\r22OCT21GD-21-001209Real Estate Sale - Sci Fa Sur Tax LienActive$51,388.64\rXX\rPlaintiff(s):Attorney for the Plaintiff:Defendant(s):PropertyMunicipalityParcel/Tax ID:\rPlaintiffs, AllMAIELLO BRUNGO & MAIELLOCopes, Willete D\r1428 PENN AVEWilkinsburg\rPITTSBURGH, PA 15221  \
# 0                                                NaN
# 1                                                NaN
# 2  Comments:9/30/21 CH13 BANKRUPTCY FILED, 21-221...
# 3  SaleCase NumberSale TypeStatusTractsCost & Tax...
# 4                                                NaN
# 5                                                NaN
# 6        Attorney for the Plaintiff:\rJeffrey D Ries
#
#                            Case Number\rGD-21-001209  \
# 0                                                NaN
# 1  Attorney for the Plaintiff:\rMAIELLO BRUNGO & ...
# 2                                                NaN
# ...
